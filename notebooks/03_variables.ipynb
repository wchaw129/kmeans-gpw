# %%
from src.loading_tickers import load_tickers_from_website

url_wig30 = r'https://www.bankier.pl/inwestowanie/profile/quote.html?symbol=WIG30'

cnames_table = load_tickers_from_website(url_wig30)
cnames_table.head()
# Out:
# Pobrano pomyślnie
#        Nazwa Ticker        Kurs  Zmiana Zmiana % Wpływ na indeks  \
# 0      ALIOR    ALR    118.4000   -0.95   -0,80%        -0,0176%
# 1    ALLEGRO    ALE     29.1200   -0.28   -0,95%        -0,0463%
# 2  ASSECOPOL    ACP    172.7000   -5.30   -2,98%        -0,0583%
# 3    BENEFIT    BFT  3 960,0000  -45.00   -1,12%        -0,0265%
# 4    BUDIMEX    BDX    743.4000  -16.40   -2,16%        -0,0428%
#
#   Udział w obrocie       Pakiet Udział w portfelu
# 0          0,9087%   88 895 000             2,21%
# 1          3,0673%  795 575 000             4,86%
# 2          1,6064%   54 071 000             1,96%
# 3          1,1626%    2 834 000             2,35%
# 4          1,1984%   12 728 000             1,98%

# %%
from src.indicators import count_indicators
import pandas as pd
company_names = cnames_table['Nazwa']
tickers = cnames_table['Ticker']
df = pd.DataFrame()

i=1
e=0
for cname, ticker in zip(company_names, tickers):
    print(f'Pobieranie {i}/30')
    try:
        info = pd.Series(count_indicators(cname, ticker, 3, 5, 2024))
    except Exception as e:
        print(f'Błąd dla spółki: {cname} \n {e} \n')
        e+=1
    df[cname] = info
    i+=1

print(f'Liczba błędów: {e}')
# Out:
# Pobieranie 1/30
# Pobieranie 2/30
# Pobieranie 3/30
# Pobieranie 4/30
# Pobieranie 5/30
# Pobieranie 6/30
# Pobieranie 7/30
# Pobieranie 8/30
# Pobieranie 9/30
# Pobieranie 10/30
# Pobieranie 11/30
# Pobieranie 12/30
# Pobieranie 13/30
# Pobieranie 14/30
# Pobieranie 15/30
# Pobieranie 16/30
# Pobieranie 17/30
# Pobieranie 18/30
# Pobieranie 19/30
# Pobieranie 20/30
# Pobieranie 21/30
# Pobieranie 22/30
# Pobieranie 23/30
# Pobieranie 24/30
# Pobieranie 25/30
# Pobieranie 26/30
# Pobieranie 27/30
# Pobieranie 28/30
# Pobieranie 29/30
# Pobieranie 30/30
# Liczba błędów: 0

# %%
data = df.transpose()

TO_DIR = r'../data/dirty/dirty_df.csv'
data.to_csv(TO_DIR)
