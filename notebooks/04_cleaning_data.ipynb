# %%
import pandas as pd

DIR = r'../data/dirty/dirty_df.csv'

data = pd.read_csv(DIR, index_col = 0)
data.head()
# Out:
#                 ROE       ROA      AAGR        DY  dynamika EPS        P/E  \
# ALIOR      0.095054  0.009196  0.582233  0.000000     13.170178   4.404444
# ALLEGRO    0.017509  0.012178  0.539843  0.000000     -0.188657  45.460689
# ASSECOPOL  0.091967  0.057254  0.146215  0.045966     15.685887   4.617202
# BENEFIT    0.275166  0.137899  1.577394  0.028244    116.942704  12.357455
# BUDIMEX    0.396130  0.063130  0.381019  0.076436     25.039765  15.237392
#
#                P/BV       std      beta
# ALIOR      0.749856  0.022132  1.463940
# ALLEGRO    3.462181  0.020661  0.772608
# ASSECOPOL  0.623846  0.014390  0.559913
# BENEFIT    4.212259  0.021075  0.781190
# BUDIMEX    7.163569  0.021308  1.075289

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, ALIOR to ZABKA
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ROE           30 non-null     float64
#  1   ROA           30 non-null     float64
#  2   AAGR          30 non-null     float64
#  3   DY            30 non-null     float64
#  4   dynamika EPS  30 non-null     float64
#  5   P/E           30 non-null     float64
#  6   P/BV          30 non-null     float64
#  7   std           30 non-null     float64
#  8   beta          30 non-null     float64
# dtypes: float64(9)
# memory usage: 2.3+ KB

# %%
data.describe()
# Out:
#              ROE        ROA       AAGR         DY  dynamika EPS         P/E  \
# count  30.000000  30.000000  30.000000  30.000000     30.000000   30.000000
# mean    0.137116   0.053932   1.351586   0.034452     37.901176   18.296369
# std     0.120379   0.045925  13.708916   0.037465    125.679382   42.813958
# min    -0.093009  -0.002526 -39.853555   0.000000     -1.073020   -7.354879
# 25%     0.044182   0.015368   0.199084   0.000000      0.726968    4.457634
# 50%     0.120875   0.039316   0.561038   0.019858      8.073665    8.530770
# 75%     0.213239   0.083378   1.325947   0.062979     15.924655   16.368419
# max     0.426778   0.169431  58.140292   0.117605    690.614498  236.926563
#
#             P/BV        std       beta
# count  30.000000  30.000000  30.000000
# mean    2.429014   0.022008   1.032222
# std     2.932839   0.004932   0.254943
# min     0.273965   0.013688   0.559913
# 25%     0.630607   0.018209   0.876107
# 50%     1.106415   0.021681   0.968953
# 75%     3.933135   0.024407   1.195914
# max    14.358652   0.035490   1.536898

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from src.processing import set_plot_style, set_plot_font, save_chart

sector_map = {
    'ALIOR': 'Finanse', 'MBANK': 'Finanse', 'MILLENNIUM': 'Finanse', 
    'PEKAO': 'Finanse', 'PKOBP': 'Finanse', 'SANPL': 'Finanse',
    'PZU': 'Finanse', 'KRUK': 'Finanse', 'XTB': 'Finanse',
    'ALLEGRO': 'Handel i Usługi', 'CCC': 'Handel i Usługi', 'DINOPL': 'Handel i Usługi', 
    'LPP': 'Handel i Usługi', 'PEPCO': 'Handel i Usługi', 'ZABKA': 'Handel i Usługi', 
    'BENEFIT': 'Handel i Usługi', 'RAINBOW': 'Handel i Usługi',
    'BUDIMEX': 'Przemysł i Energetyka', 'KETY': 'Przemysł i Energetyka', 
    'ENEA': 'Przemysł i Energetyka', 'PGE': 'Przemysł i Energetyka', 
    'TAURONPE': 'Przemysł i Energetyka', 'PKNORLEN': 'Przemysł i Energetyka', 
    'JSW': 'Przemysł i Energetyka', 'KGHM': 'Przemysł i Energetyka',
    'ASSECOPOL': 'Technologia', 'CDPROJEKT': 'Technologia', 
    'CYFRPLSAT': 'Technologia', 'ORANGEPL': 'Technologia', 'SYNEKTIK': 'Technologia'
}

set_plot_style()
set_plot_font()
sector_data = pd.Series(sector_map)
plt.figure(figsize = (8, 4))
sns.countplot(x = sector_data, width = 0.55, palette="binary")

plt.yticks(np.arange(11))
plt.xlabel('')
plt.ylabel('liczba spółek w sektorze')
save_chart('chart4')
# Out:
# C:\Users\Wiktor\AppData\Local\Temp\ipykernel_27664\274930687.py:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = sector_data, width = 0.55, palette="binary")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from src.processing import set_plot_font, save_chart

st_data = (data - data.mean())/data.std(ddof = 0)
set_plot_font()
plt.figure(figsize = (8,4))
sns.boxplot(data = st_data, palette = 'grey')
save_chart('boxplot_all')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from src.processing import set_plot_font, save_chart
set_plot_font()
sns.heatmap(data.corr('spearman'), annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1, center=0, linewidths=0.5, cbar_kws={"shrink": .8})
plt.tight_layout()
save_chart('corr_heatmap')
